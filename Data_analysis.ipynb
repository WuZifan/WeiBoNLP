# %%
import sklearn as sk
import pandas as pd
import scipy as scp

# %%
pro_data=pd.read_csv('processed_data.csv')

# %%
pro_data.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  comment       create_time  like  \
# 0           0             0           11800     3939  2015-08-17 20:41  3197
# 1           1             1           11801      511  2015-08-17 21:38   747
# 2           2             2           11802      542  2015-08-17 22:07  2846
# 3           3             3           11803      723  2015-08-17 23:25  4774
# 4           4             4           11804       96  2015-08-17 23:59   828
#
#   locate  repost                                              title  \
# 0      无    7019  BBC推送： 7点25分左右泰国曼谷市中心发生大爆炸.... 在市中心旅游景点四面佛附近.....
# 1      无    1097  BBC推送： 7点25分左右泰国曼谷市中心发生大爆炸.... 在市中心旅游景点四面佛附近.....
# 2      无    1328  话说。最近几年来，各种保守老旧的名字已经不能满足英国人了.... 最近英国公布了一份新生儿姓...
# 3      无     596  话说，有个妹纸最近做了个实验：【素颜的妹纸，美图前和美图后，约会软件上的男人们都会有怎样的反...
# 4      无     244  【体验-伦敦】谁说看电影只能啃爆米花的？号称电影院里伙食最好的Edible Cinema把自...
#
#            tools                        ...                          \
# ...

# %%
pro_data.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'Unnamed: 0.1.1', 'comment',
#        'create_time', 'like', 'locate', 'repost', 'title', 'tools', 'like_nor',
#        'repost_nor', 'comment_nor', 'fuhao', 'huati1', 'huati2', 'biaoqing',
#        'cut_words', 'word_bag', 'tf_idf', 'tf_idf_top5'],
#       dtype='object')
