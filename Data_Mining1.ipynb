# %% [markdown]
# # LDA主题发现
#
#     0、下面主要是通过LDA对文档进行主题发现，操作过程如下。
#
#     1、加载语料，语料未分词；加载停用词。
#     2、为了能够简化后续计算，希望对每个语料进行关键词提取，并利用关键词进行后续操作。关键词提取步骤：
#         2.1 关键词采用的TF-IDF对词进行排序的思路。
#         2.2 因此生成每个词的在整个语料中的出现次数的dict。
#         2.3 逐个语料计算其中每个词汇的TF-IDF值，并根据所需数目提取前k个词作为该语料的关键词。
#     3、得到关键词后，重新生成词袋模型（LDA采用的是词袋模型）
#     4、定义需要区分的主题数，跑就行了。
#     5、对于每个语料，将其转换为词袋模型，即可进行主题的划分。

# %%
import pandas as pd
import numpy as np
import jieba as jb
import jieba.posseg as pseg
import jieba.analyse
from gensim import corpora, models
import matplotlib.pyplot as plt
import math

# %%
'''
加载原始语料数据
'''
raw_data=pd.read_csv('left_11335.csv')

# %%
'''
加载停用词
'''
stop_list=[]
fff=open('stop_words.txt','r',encoding='utf-8')
for li in fff:
    stop_list.append(li[:-1])
fff.close()

# %% [markdown]
# # 提取关键词
#
#
#     0、需要更新自己的tf-idf库
#     1、将语料进行分词，去除停用词，去除指定词性之外的词，得到每个语料的分词结果。
#     2、计算每个词在整个语料中出现的次数，作为自定义的IDF表。
#     3、将自定义的IDF表导入jieba，利用结巴的extract（背后是TF-IDF），来得到每个语料关键词。

# %%
'''
得到自定义的idf表格
'''
all_dict = {}
total=0
final_dict={}
new_line=[]
weibos=raw_data['title'].tolist()
# 定义需要的词性
target_attr=['n','ns','nr','nt','nz','v','a']
for i,line in enumerate(weibos):
    temp_dict = {}
    # 统计有多少文档
    total += 1
    # 分词
    cut_line = pseg.cut(line)
    # 该文档的词语去重
    for word,flag in cut_line:
        # 过滤停用词，以及过滤非指定词性
        if word not in stop_list and flag in target_attr:
            temp_dict[word] = 1
    new_line.append(''.join(temp_dict))
    # 更新这个词在每个文档中出现过多少次
    for key in temp_dict.keys():
        num = all_dict.get(key, 0)
        all_dict[key] = num + 1

# 计算每个词的TF-IDF值。
for key in all_dict:
    w = key
    p = '%.10f' % (math.log10(total/(all_dict[key] + 1)))
    final_dict[w]=p

fff=open('my_idf.txt.big','w',encoding='utf-8')
fff.write( '\n'.join([ w+' '+f for w,f in zip(final_dict.keys(),final_dict.values())]))
fff.close()

# %%
final_dict.keys()
# Out:
# dict_keys(['推送', '分', '泰国', '曼谷', '市中心', '发生', '爆炸', '旅游景点', '记者', '现场', '伤亡', '话', '说', '保守', '旧', '名字', '英国人', '英国', '公布', '新生儿', '姓名', '调查报告', '权力', '游戏', '人物', '宝宝', '起名', '妹纸', '做', '素颜', '图', '约会', '软件', '男人', '反差', '数量', '差', '感受', '体验', '伦敦', '电影', '只能', '啃', '爆米花', '号称', '电影院', '伙食', '自制', '美食', '观影', '神秘', '小盒子', '放', '美味', '小吃', '精心', '编', '号码', '让你在', '精彩', '时刻', '享受', '味蕾', '视觉', '双重', '放映', '想去', '介绍', '世界', '年龄', '四胞胎', '母亲', '生', '孩子', '最小', '红', '吸血', '猫', '虎牙', '天生', '主人', '恶煞', '萌', '脸', '对得起', '有没有', '想', '西瓜', '哥哥', '米其林', '餐厅', '请到', '厨', '超', '迎接', '回家', '可爱', '妹', '抖', '节目', '好玩', '抽奖', '环节', '拍', '精美', '手', '办', '等你拿', '主', '爱心', '转发', '微博', '抽', '支付宝', '扮演', '蝙蝠侠', '儿童医院', '探望', '生病', '小朋友', '视频', '响应', '慈善', '团体', '邀请', '带来', '勇气', '高速公路', '故障', '蝙蝠', '车', '撞', '身亡', '英雄', '蜡烛', '穿着', '内衣', '站', '繁华', '广场', '爱惜', '身体', '事情', '鼓励', '读书', '温馨', '公交车', '读', '免票', '流浪狗', '喂成', '大肥', '汪', '华丽', '瘦身', '成功', '美女', '学业成绩', '理想', '担心', '机会', '名校', '学习', '集团', '提供', '包含', '预科', '国际', '硕士', '课程', '通过率', '高达', '拥有', '超过', '大学', '道路', '贝勒', '调戏', '关键时刻', '救', '小哥', '命', '吃货', '妹子', '简单', '马克杯', '早餐', '小伙伴', '时间', '精力', '早饭', '吃到', '份量', '文章', '玩', '爱', '假装', '人工', '翻译', '君', '小尾巴', '关注', '带上', '话题', '发布', '图片', '文字', '抽取', '普吉岛', '自助游', '大奖', '帆船', '酒店', '吃', '三明治', '悠哉', '度假', '自娱自乐', '详情', '戳', '下图', '错觉', '跑', '酷', '合辑', '炫', '北极熊', '加拿大', '摄影师', '拍下', '雪', '抓', '海豹', '改玩', '花', '公举', '女儿', '控', '老爹', '透透', '捧', '手心', '爹', '力', '天际', '控大', '布布', '庆祝', '入驻', '中国', '寺库', '奢侈品', '网站', '上线', '皇家', '钟爱', '包', '享有', '造', '包袋', '无需', '等待', '关税', '考考', '网', '价格', '提示', '品牌', '大牌', '齐聚', '置顶', '写出', '答案', '送', '工作犬', '法庭', '安慰', '出庭作证', '证人', '安抚', '目睹', '事件', '心灵', '中学', '请来', '老师', '经历', '学生', '叛逆', '展示', '中国式', '因材施教', '补课', '扔', '实心球', '国旗', '讲话', '扇子舞', '班', '赢', '三科', '全胜', '内容', '审核', '整理', '版', '找', '外遇', '慌', '黑', '黑客', '下载', '数据库', '关闭', '用户', '资料', '裸照', '性幻想', '银行', '信息', '地址', '管理员', '疯', '中式', '英式', '网友', '纪录片', '播完', '报纸', '报道', '评论', '炸', '老外', '圈子里', '最火', '手机', '修图', '迪拜', '开', '出租车', '乘客', '主题乐园', '攒钱', '载', '有心', '爱尔兰', '逛', '游乐园', '故事', '黑衣人', '守护者', '地球', '高', '达', '行星', '发现', '提早', '外星人', '适合', '观看', '准备就绪', '全黑', '队', '明星', '球员', '变', '经典', '演绎', '创意', '无限', '回答', '赢取', '大黑', '礼', '新西兰', '航空', '德国大众', '工程师', '问', '粉丝', '改造', '东西', '变得', '美好', '刹车', '婴儿车', '德国', '做出', '功能', '事儿', '发', '记录片', '想起', '念', '校长', '晚自习', '补习', '引进', '教学方法', '课余', '环境', '念书', '英', '教学模式', '老爷爷', '路', '种下', '英里', '长', '向日葵', '动人', '想要', '摆脱', '学生宿舍', '拘束', '单调', '潮', '爆了', '学生公寓', '值得', '姑娘', '小混混', '袭击', '路过', '带回', '意外', '惊喜', '碰到', '红绿灯', '停不下', '来应', '个景', '浪漫', '阴天', '繁星', '粉', '屋子', '吸', '鸡尾酒', '吸到', '爽', '棒', '露天', '泳池', '露天电影', '假扮', '许仙', '白娘子', '唱渡', '情', '应', '前提', '单身', '波兰人', '集体', '罢工', '上班', '医院', '捐血', '大英', '没用', '尿点', '卡丁车', '彩弹', '枪', '重拍', '追车', '不用', '特效', '拍出', '满满', '大片', '感', '超燃', '单细胞', '男', '买单', '孤单', '请', '帮', '害羞', '胖', '爸爸', '脑部', '受损', '儿子', '病魔', '作', '约定', '复健', '减肥', '能站', '减掉', '暖', '心', '内华达', '火人', '沙漠', '文化节', '主题', '雕塑', '感觉', '应景', '成绩', '渣渣', '翻身', '卡', '分线', '脱贫', '刷分', '过级', '独家', '分数段', '精准', '歌手', '发行', '新', '单曲', '效果', '颜色', '基调', '支', '感动', '观众', '痛失', '亲人', '照片', '缅怀', '天堂', '网络红人', '模仿', '表情', '颜', '任性', '毕业', '梦', '开车', '北极', '中断', '一辆车', '笑', '曝光', '消息', '数学老师', '短缺', '学校', '数学课', '体育老师', '教', '夫妻', '喜欢', '养娃', '爱狗', '打算', '爹妈', '泰迪', '娃养', '爸妈', '家庭', '恩', '狗娃', '肉夹馍', '建筑', '学院', '车站', '荒地', '成', '城市园林', '布置', '忙碌', '浇', '浇花', '菜', '很好', '减压', '方式', '体会', '农家乐', '结束', '花园里', '种出', '农家菜', '涂鸦', '大师', '主题公园', '看过', '出门', '大结局', '改变', '联手', '万能', '淘宝', '张', '淘', '至尊', '礼遇', '好友', '宅', '洗衣', '推拿', '汽车', '附赠', '生猛', '大闸蟹', '换', '姿势', '哥们', '父亲', '大寿', '地球仪', '市面上', '卖', '走心', '烂', '沉心', '钻研', '手艺', '工作室', '走上', '创业', '发家', '强对流', '暴雨', '下沉', '气流', '云', '雨', '跟着', '地面', '远', '上帝', '泼', '一大', '盆水', '拍到', '后腿', '吉娃娃', '安乐死', '夫妇', '拯救', '过换', '教师', '顶级', '私立学校', '教学', '优秀', '课堂', '纪律', '深厚', '文化', '积淀', '寄宿制', '自律', '精英', '寄宿', '诠释', '律师', '杀手', '辩护', '离开', '电话', '举办', '婚礼',  ...

# %%
'''
加载自定义的idf表格，并进行关键词提取
'''
jb.analyse.set_idf_path('my_idf.txt.big')
key_words=[]
for i in range(raw_data.shape[0]):
    weibo=raw_data.loc[i,'title']
    weibo=''.join(weibo.split())
    
    k_w=jieba.analyse.extract_tags(weibo, topK=15, withWeight=False,allowPOS=('n','ns','nr',
                                                                                'nt','nz','ng','i','v','a'))
    k_w=[wd for wd in k_w if str(wd) not in stop_list]
    key_words.append(k_w)

# %%
raw_data['key_words']=key_words

# %% [markdown]
# # 生成LDA模型
#
#     1、根据每个语料的关键词，生成语料的词袋表示
#     2、训练lda模型，并展示。
#     3、对每个语料进行预测，选择概率最大的主题作为他们的分类

# %%
'''
生成语料的关键词表示
生成语料的词袋表示
'''
# 词袋字典
word_dict=corpora.Dictionary(key_words)
print(len(word_dict))
# 语料的词袋表示
corpus_list = [word_dict.doc2bow(text) for text in key_words]
print(len(corpus_list))
# Out:
# 21710
# 11335

# %%
'''
训练lda模型
'''
lda = models.ldamodel.LdaModel(corpus=corpus_list,id2word=word_dict,num_topics=10,alpha='auto')

# %%
'''
展示头5个模型
'''
lda.print_topics(10)
# Out:
# [(0,
#   '0.027*"视频" + 0.017*"拍" + 0.010*"秒" + 0.008*"英国" + 0.008*"胡椒" + 0.008*"孩子" + 0.006*"小哥" + 0.005*"笑" + 0.005*"吃" + 0.005*"妈妈"'),
#  (1,
#   '0.054*"秒" + 0.048*"视频" + 0.047*"英国" + 0.044*"事儿" + 0.043*"拍" + 0.013*"屎" + 0.013*"铲" + 0.011*"笑" + 0.011*"官" + 0.008*"允悲"'),
#  (2,
#   '0.017*"波" + 0.014*"网友" + 0.013*"笑" + 0.012*"摊手" + 0.011*"视频" + 0.009*"拍" + 0.007*"推" + 0.007*"开心" + 0.007*"说" + 0.006*"允悲"'),
#  (3,
#   '0.012*"抱抱" + 0.011*"英国" + 0.009*"妹子" + 0.006*"小哥" + 0.005*"成" + 0.005*"说" + 0.004*"视频" + 0.004*"萌" + 0.004*"世界" + 0.004*"唱"'),
#  (4,
#   '0.013*"心" + 0.008*"美好" + 0.006*"好看" + 0.006*"世界" + 0.006*"看似" + 0.005*"网友" + 0.005*"故事" + 0.005*"照片" + 0.005*"操作" + 0.004*"袭"'),
#  (5,
#   '0.012*"英国" + 0.007*"视频" + 0.007*"伦敦" + 0.007*"偷笑" + 0.005*"妹子" + 0.005*"精致" + 0.004*"世界" + 0.004*"现场" + 0.004*"强奸" + 0.004*"吃"'),
#  (6,
#   '0.018*"跪" + 0.010*"英国" + 0.010*"网友" + 0.008*"小哥" + 0.007*"想" + 0.006*"笑" + 0.006*"说" + 0.006*"画风" + 0.006*"做" + 0.005*"人生"'),
#  (7,
#   '0.014*"可爱" + 0.009*"开心" + 0.009*"妹子" + 0.008*"爱" + 0.008*"心" + 0.007*"笑" + 0.006*"厉害" + 0.006*"萌" + 0.006*"视频" + 0.005*"时间"'),
#  (8,
#   '0.012*"美国" + 0.009*"娃" + 0.006*"想" + 0.006*"英国" + 0.005*"摄影师" + 0.005*"无比" + 0.005*"视频" + 0.004*"说" + 0.004*"川普" + 0.004*"感觉"'),
#  (9,
#   '0.017*"吃惊" + 0.014*"梦" + 0.008*"视频" + 0.006*"女性" + 0.005*"面对" + 0.005*"美国" + 0.005*"笑" + 0.005*"汪星" + 0.004*"憧憬" + 0.004*"流浪"')]

# %%
'''
展示第i个主题
'''
for i in range(10):
    print(i,lda.print_topic(i,5))
    print()
# Out:
# 0 0.027*"视频" + 0.017*"拍" + 0.010*"秒" + 0.008*"英国" + 0.008*"胡椒"
#
# 1 0.054*"秒" + 0.048*"视频" + 0.047*"英国" + 0.044*"事儿" + 0.043*"拍"
#
# 2 0.017*"波" + 0.014*"网友" + 0.013*"笑" + 0.012*"摊手" + 0.011*"视频"
#
# 3 0.012*"抱抱" + 0.011*"英国" + 0.009*"妹子" + 0.006*"小哥" + 0.005*"成"
#
# 4 0.013*"心" + 0.008*"美好" + 0.006*"好看" + 0.006*"世界" + 0.006*"看似"
#
# 5 0.012*"英国" + 0.007*"视频" + 0.007*"伦敦" + 0.007*"偷笑" + 0.005*"妹子"
#
# 6 0.018*"跪" + 0.010*"英国" + 0.010*"网友" + 0.008*"小哥" + 0.007*"想"
#
# 7 0.014*"可爱" + 0.009*"开心" + 0.009*"妹子" + 0.008*"爱" + 0.008*"心"
#
# 8 0.012*"美国" + 0.009*"娃" + 0.006*"想" + 0.006*"英国" + 0.005*"摄影师"
#
# 9 0.017*"吃惊" + 0.014*"梦" + 0.008*"视频" + 0.006*"女性" + 0.005*"面对"

# %%
key_words[0]
# Out:
# ['市中心', '分', '泰国', '曼谷', '发生', '爆炸', '旅游景点', '记者', '现场', '伤亡', '推送']

# %%
'''
预测
'''
test_dict=word_dict.doc2bow(key_words[0])
res=lda[test_dict]
print(res)
np.sum([ttt[1] for ttt in res])
# Out:
# [(2, 0.6641561), (5, 0.15530746), (8, 0.119792685)]
# 0.93925625

# %%
'''
预测每个语料
'''
key_words_list=raw_data['key_words'].tolist()
cate_list=[]
for kw in key_words:
    test_dict=word_dict.doc2bow(kw)
    res=lda[test_dict]
    res.sort(key=lambda x:x[1],reverse=True)
    cate_list.append(res[0][0])
raw_data['topic_cate']=cate_list

# %%
raw_data['topic_cate'].value_counts()
# Out:
# 1    1742
# 0    1316
# 6    1274
# 2    1152
# 3    1046
# 8    1024
# 5     985
# 7     940
# 4     930
# 9     926
# Name: topic_cate, dtype: int64

# %%
raw_data[raw_data['topic_cate']==9]
# Out:
#        comment   like  repost  \
# 3          723   4774     596
# 48         522   2328     437
# 49          79    889     231
# 117         77    659     247
# 125        369   2081    2470
# 131       3016   3795    2002
# 145       1243   4749    3380
# 153       1000   5279     921
# 164         43    249     450
# 183        586   1538    1365
# 186        484   2786     918
# 188       4473  12350   11614
# 201        715   2327     935
# 207       2777  10012    8882
# 216        277   3472     348
# 217         44    374     198
# 239        745   1465    2207
# 277         31    269      70
# 282        543   7024     845
# 288       9184  36960   15730
# 320         22    381     104
# 330        645   4304     908
# 336        675   2033    1462
# 343        603   3792    1527
# 369        444   2564     483
# 390         49    254      38
# 395       1192    579   11188
# 427        909   6146    3126
# 436        416   1008     699
# 447         15    270      59
# ...        ...    ...     ...
# 10997      186    143     417
# 11020      187   1433    1249
# 11040      287   1147     261
# 11044      214   2592    1624
# 11048      458   3904     457
# 11063      943   7281    1417
# 11064      425   3695    2132
# 11074       85   1744    1796
# 11080      235    749     728
# 11081      126   2287     627
# 11092      502   1196     445
# 11098      830   3269     704
# 11100       72    582     224
# 11105     3700  25183    3843
# 11132      741    790     635
# 11138      361    185     485
# 11140      923   5934    2656
# 11150      622   2096    1291
# 11168      478   3255     800
# 11186      367   4398     673
# 11191      807   3881     910
# 11217       71    110      10
# 11238      356   3075     567
# 11241      174   1332     609
# 11254      438   2148     449
# 11270      535   2516     832
# 11281      247   1888     489
# 11307     1562   2377    1493
# 11328      174    303     445
# 11332      837  10637    5623
#
#                                                    title  \
# 3      话说，有个妹纸最近做了个实验：【素颜的妹纸，美图前和美图后，约会软件上的男人们都会有怎样的反...
# 48                            伦敦七夕怎么玩？ 敢不敢今晚带个妹纸去吃肉夹馍？？
# 49     【体验-伦敦】最近UCL建筑学院的学生把Kings Cross车站后面的荒地改造成了一个城市...
# 117    【户外-伦敦】看着碟中谍5里阿汤哥酷炫的装备和超燃的任务场面，你是不是已经摩拳擦掌好久了？D...
# 125    油管上最近超级火的舞蹈，蛮酷的，律动感十足，搭上音乐感觉都要跳起来了，棒！！[赞]http/...
# 131          今天莎莎在香港铜锣湾搞了个用支付宝就打五折活动，感觉一下子现场就沸腾了。。。。。。
# 145    一个法国艺术家Charles Petillion最近在伦敦Covent Garden建造的一...
# 153    因为在车里发现了一大包白色的物质... 一个哥们被警方以涉嫌持有冰毒逮捕被关了起来........
# 164    1分钱抢个钻石王老五男友约会，还送1克拉钻石戒指！转发并@ 3位好友，即有机会获得@全城热恋...
# 183                      几个非常实用的神技能，分分钟学起来，拿去装逼吧！[doge]
# 186    澳洲布里斯班一户人家的一对名叫BlueBoys的斗牛㹴....... 乖.. 爱卖萌.......
# 188    BBC《中国的秘密（二）：中国式婚姻 》BBC表示，在中国结婚不是一种选择而是一种义务。 为...
# 201    100年看遍女性睡衣变迁...... 那个团队又出的新作... 100年，从简约保守，到逐渐...
# 207                   要不是因为我饿晕了哼......... 为了抓条鱼吃我容易么-。-
# 216    最近有个哥们.... 一天在上班途中遇到了一只流浪的大羊驼宝宝....... 他直接把它捡上...
# 217    9月7日，一起玩点新东西。转发本微博并关注@即刻 我们将通过@转发抽奖平台 抽选1名幸运者赠...
# 239     真是凶残，连快餐都可以这么玩，岛国还有什么干不出？[吃惊]http//t.cn/Ryy17ym
# 277    #天猫月光节# 传说，月光有一种神奇的魔力，能照出人内心中另一个自己，及你最需要的东西！够胆...
# 282    深夜.. 大桥旁.... 一个想自杀的人..... 一个路过的警察..... 一个深深的拥抱...
# 288    深挖： 拍出BBC【中国的秘密】系列的那个女主持人...就是个不折不扣的问题少女.........
# 320    我们相信，#每个认真生活的人都值得被认真对待#，而我们就站在他们背后，尽我所能。这是蚂蚁金服...
# 330    女儿4岁生日.... 想要一个【绿巨人公举】的生日蛋糕.... 结果，这老爸真的给她做出来了...
# 11100  [牙齿, 美白, 功课, 导致, 佩戴, 牙套, 清洁, 到位, 食物, 色素, 残留, 颜...           9
# 11105   [面对, 层出不穷, 咸猪, 手, 霓虹, 男, 站, 实在, 想, 乱摸, 找, 摊手, 跪]           9
# 11132  [视频, 摩根, 曼, 骚扰, 女性, 挖出, 采访, 实锤, 吃惊, 短裙, 调侃, 算是...           9
# 11138          [选择, 坚守, 心, 梦想, 换, 环境, 前行, 转发, 位, 好友, 说出]           9
# 11140  [女人, 公民, 公投, 推翻, 禁止, 堕胎, 法案, 离婚, 国家, 女性, 抗争, 拼...           9
# 11150  [女性, 权利, 奔走, 革命家, 达, 目的, 不惜, 罪犯, 英雄, 恐怖分子, 难, ...           9
# 11168     [工艺, 华丽, 精美, 张开, 闭合, 妹子, 手工, 翅膀, 维密, 考虑一下, 憧憬]           9
# 11186           [狗子, 一家人, 打算, 领养, 朋友, 绝配, 小猫咪, 奇迹般地, 开心]           9
# 11191                                  [男人, 娃, 作出, 妖, 笑]           9
# 11217  [银行, 平安, 无限, 预备, 拥有, 超越, 想要, 股份制, 招募, 天生, 不安分,...           9
# 11238  [说, 上有政策, 面对, 重重, 规则, 想出, 机智, 应对, 办法, 机灵鬼, 费解, 笑]           9
# 11241  [视频, 放眼望去, 沙滩, 浮, 水面, 岩石, 梦, 吃惊, 风平浪静, 来到, 神奇,...           9
# 11254  [荷兰, 王后, 亲, 妹妹, 学有所成, 心理学家, 钻研, 自杀, 相关, 现象, 验证...           9
# 11270  [教会, 性丑闻, 吹出, 商业, 帝国, 追, 海瑟薇, 相恋, 克林顿, 站台, 揭穿,...           9
# 11281                       [晕, 金属, 防护网, 编起来, 梦, 吃惊, 允悲]           9
# 11307  [姨妈, 无法控制, 狂躁, 不安, 身体, 疼痛, 选择, 切除, 子宫, 婚姻, 遭遇,...           9
# 11328  [世界杯, 小龙虾, 开幕, 中国, 队, 身着, 番茄, 炒蛋, 配色, 球衣, 走来, ...           9
# 11332                 [迷恋, 世界, 小哥, 时期, 作品, 网友, 呆, 梦, 吃惊]           9
#
# [926 rows x 6 columns]

# %% [markdown]
# # 结果分析
#
#     1、利用jieba提供的接口提取关键字，背后应该是采用TF-IDF进行提取的。我们人为的指定了词性。
#     2、利用gensim提供的接口训练的LDA，并对每一个文本进行主题分类。
#     3、发现其实主题分类的结果和人的直觉有一定差距。
#     4、之后可能会希望从两个方面改进分类结果：
#         4.1 提取关键词时，对词汇的词性再做更优化的限定。
#         4.2 尝试使用较为精细的LDA分类方法，并使用阈值来过滤分类。
#         4.3 是否需要考虑分类间的相似性？
#
#     5、总的来看，LDA的效果并不是特别的理想，原因在哪里？
#         5.1 细节上看，可能是我们对语料的清洗提取程度不够，无法给出合适的词汇。
#         5.2 但是横向对比上，我觉得更有可能的是，语料本身并没有很直观的主题。
#            LDA在新闻类的语料上效果可以，是因为新闻类语料的主题明显，每个主题下的词汇差异性比较大。
#         5.3 考虑情感分析，对每条文本的情感情感进行分类。
